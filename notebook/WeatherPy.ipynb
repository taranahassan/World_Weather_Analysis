# %%
# importing dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# creating set of random latitude and longitude numbers.
lats = np.random.uniform(-90, 90, size=1800)
lngs = np.random.uniform(-180, 180, size=1800)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# adding latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# importing citipy module
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 702

# %%
# importing citipy module
from citipy import citipy

# %%
# import requests library
import requests

# %%
# import API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | george
# Processing Record 3 of Set 1 | puerto ayora
# Processing Record 4 of Set 1 | ribeira grande
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | cassia
# Processing Record 7 of Set 1 | havelock
# Processing Record 8 of Set 1 | maumere
# Processing Record 9 of Set 1 | hobart
# Processing Record 10 of Set 1 | yulara
# Processing Record 11 of Set 1 | khatanga
# Processing Record 12 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 1 | savinka
# Processing Record 14 of Set 1 | ancud
# Processing Record 15 of Set 1 | namatanai
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 1 | kodiak
# Processing Record 20 of Set 1 | tasiilaq
# Processing Record 21 of Set 1 | tiksi
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | cape town
# Processing Record 27 of Set 1 | umm kaddadah
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | shibetsu
# Processing Record 30 of Set 1 | jvari
# Processing Record 31 of Set 1 | qaanaaq
# Processing Record 32 of Set 1 | tilichiki
# Processing Record 33 of Set 1 | bethel
# Processing Record 34 of Set 1 | beringovskiy
# Processing Record 35 of Set 1 | igarka
# Processing Record 36 of Set 1 | kaya
# Processing Record 37 of Set 1 | pingliang
# Processing Record 38 of Set 1 | longyearbyen
# Processing Record 39 of Set 1 | jamui
# Processing Record 40 of Set 1 | mahebourg
# Processing Record 41 of Set 1 | acaponeta
# Processing Record 42 of Set 1 | diamantino
# Processing Record 43 of Set 1 | guerrero negro
# Processing Record 44 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 1 | vestmanna
# Processing Record 46 of Set 1 | egvekinot
# Processing Record 47 of Set 1 | chuy
# Processing Record 48 of Set 1 | umba
# Processing Record 49 of Set 1 | hermanus
# Processing Record 50 of Set 1 | salalah
# Processing Record 1 of Set 2 | pringsewu
# Processing Record 2 of Set 2 | hithadhoo
# Processing Record 3 of Set 2 | severo-kurilsk
# Processing Record 4 of Set 2 | upernavik
# Processing Record 5 of Set 2 | mar del plata
# Processing Record 6 of Set 2 | ponta do sol
# Processing Record 7 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 2 | nenjiang
# Processing Record 9 of Set 2 | port elizabeth
# Processing Record 10 of Set 2 | kokopo
# Processing Record 11 of Set 2 | los llanos de aridane
# Processing Record 12 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 2 | bambous virieux
# Processing Record 14 of Set 2 | port hedland
# Processing Record 15 of Set 2 | rikitea
# Processing Record 16 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 17 of Set 2 | shingu
# Processing Record 18 of Set 2 | cidreira
# Processing Record 19 of Set 2 | lwowek slaski
# Processing Record 20 of Set 2 | cherskiy
# Processing Record 21 of Set 2 | mata
# Processing Record 22 of Set 2 | the valley
# Processing Record 23 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 2 | zabol
# Processing Record 25 of Set 2 | ust-barguzin
# Processing Record 26 of Set 2 | kapaa
# Processing Record 27 of Set 2 | atuona
# Processing Record 28 of Set 2 | new norfolk
# Processing Record 29 of Set 2 | torbay
# Processing Record 30 of Set 2 | grootfontein
# Processing Record 31 of Set 2 | manta
# Processing Record 32 of Set 2 | butaritari
# Processing Record 33 of Set 2 | olafsvik
# Processing Record 34 of Set 2 | maniitsoq
# Processing Record 35 of Set 2 | lompoc
# Processing Record 36 of Set 2 | touros
# Processing Record 37 of Set 2 | thompson
# Processing Record 38 of Set 2 | muravlenko
# Processing Record 39 of Set 2 | saint-philippe
# Processing Record 40 of Set 2 | bay roberts
# Processing Record 41 of Set 2 | lagoa
# Processing Record 42 of Set 2 | kruisfontein
# Processing Record 43 of Set 2 | antalaha
# Processing Record 44 of Set 2 | bredasdorp
# Processing Record 45 of Set 2 | eyl
# Processing Record 46 of Set 2 | sharjah
# Processing Record 47 of Set 2 | fairbanks
# Processing Record 48 of Set 2 | palmer
# Processing Record 49 of Set 2 | pevek
# Processing Record 50 of Set 2 | nikolskoye
# Processing Record 1 of Set 3 | svetlogorsk
# Processing Record 2 of Set 3 | luderitz
# Processing Record 3 of Set 3 | saint marys
# Processing Record 4 of Set 3 | calama
# Processing Record 5 of Set 3 | maple creek
# Processing Record 6 of Set 3 | katsuura
# Processing Record 7 of Set 3 | sisimiut
# Processing Record 8 of Set 3 | tuktoyaktuk
# Processing Record 9 of Set 3 | maseru
# Processing Record 10 of Set 3 | iqaluit
# Processing Record 11 of Set 3 | buin
# Processing Record 12 of Set 3 | ciudad bolivar
# Processing Record 13 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 3 | hagonoy
# Processing Record 15 of Set 3 | nakhon phanom
# Processing Record 16 of Set 3 | kemijarvi
# Processing Record 17 of Set 3 | biak
# Processing Record 18 of Set 3 | saldanha
# Processing Record 19 of Set 3 | huarmey
# Processing Record 20 of Set 3 | la ronge
# Processing Record 21 of Set 3 | hirosaki
# Processing Record 22 of Set 3 | sioux lookout
# Processing Record 23 of Set 3 | veraval
# Processing Record 24 of Set 3 | bubaque
# Processing Record 25 of Set 3 | kocevje
# Processing Record 26 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 27 of Set 3 | vaini
# Processing Record 28 of Set 3 | cockburn town
# Processing Record 29 of Set 3 | ouadda
# Processing Record 30 of Set 3 | bathsheba
# Processing Record 31 of Set 3 | norman wells
# Processing Record 32 of Set 3 | naze
# Processing Record 33 of Set 3 | taganak
# Processing Record 34 of Set 3 | port alfred
# Processing Record 35 of Set 3 | port augusta
# Processing Record 36 of Set 3 | vermilion
# Processing Record 37 of Set 3 | castro
# Processing Record 38 of Set 3 | den helder
# Processing Record 39 of Set 3 | yellowknife
# Processing Record 40 of Set 3 | saskylakh
# Processing Record 41 of Set 3 | dikson
# Processing Record 42 of Set 3 | nanortalik
# Processing Record 43 of Set 3 | darnah
# Processing Record 44 of Set 3 | hami
# Processing Record 45 of Set 3 | nepomuceno
# Processing Record 46 of Set 3 | lebu
# Processing Record 47 of Set 3 | cabo san lucas
# Processing Record 48 of Set 3 | maghama
# City not found. Skipping...
# Processing Record 49 of Set 3 | sao filipe
# Processing Record 50 of Set 3 | oranjestad
# Processing Record 1 of Set 4 | ekhabi
# Processing Record 2 of Set 4 | tadepallegudem
# Processing Record 3 of Set 4 | port blair
# Processing Record 4 of Set 4 | talnakh
# Processing Record 5 of Set 4 | mercedes
# Processing Record 6 of Set 4 | basoko
# Processing Record 7 of Set 4 | leon valley
# Processing Record 8 of Set 4 | villa alemana
# Processing Record 9 of Set 4 | kahului
# Processing Record 10 of Set 4 | harper
# Processing Record 11 of Set 4 | yanchukan
# City not found. Skipping...
# Processing Record 12 of Set 4 | russellville
# Processing Record 13 of Set 4 | fortuna
# Processing Record 14 of Set 4 | luanda
# Processing Record 15 of Set 4 | hilo
# Processing Record 16 of Set 4 | boyolangu
# Processing Record 17 of Set 4 | narsaq
# Processing Record 18 of Set 4 | faanui
# Processing Record 19 of Set 4 | camacha
# Processing Record 20 of Set 4 | saurimo
# Processing Record 21 of Set 4 | yatou
# Processing Record 22 of Set 4 | hunterville
# Processing Record 23 of Set 4 | sibu
# Processing Record 24 of Set 4 | bandarbeyla
# Processing Record 25 of Set 4 | batalha
# Processing Record 26 of Set 4 | cocorit
# Processing Record 27 of Set 4 | winnemucca
# Processing Record 28 of Set 4 | tautira
# Processing Record 29 of Set 4 | jatiroto
# Processing Record 30 of Set 4 | carnarvon
# Processing Record 31 of Set 4 | pekalongan
# Processing Record 32 of Set 4 | hasaki
# Processing Record 33 of Set 4 | tonantins
# Processing Record 34 of Set 4 | khuzhir
# Processing Record 35 of Set 4 | grand-lahou
# Processing Record 36 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 4 | tubruq
# City not found. Skipping...
# Processing Record 38 of Set 4 | nizwa
# Processing Record 39 of Set 4 | nago
# Processing Record 40 of Set 4 | mazatlan
# Processing Record 41 of Set 4 | kralendijk
# Processing Record 42 of Set 4 | leningradskiy
# Processing Record 43 of Set 4 | oktyabrskiy
# Processing Record 44 of Set 4 | ixtapa
# Processing Record 45 of Set 4 | ambulu
# Processing Record 46 of Set 4 | beloha
# Processing Record 47 of Set 4 | aklavik
# Processing Record 48 of Set 4 | bombay
# Processing Record 49 of Set 4 | sao joao da barra
# Processing Record 50 of Set 4 | ippy
# Processing Record 1 of Set 5 | siguiri
# Processing Record 2 of Set 5 | crab hill
# City not found. Skipping...
# Processing Record 3 of Set 5 | jalu
# Processing Record 4 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 5 of Set 5 | klaksvik
# Processing Record 6 of Set 5 | angoche
# Processing Record 7 of Set 5 | dwarka
# Processing Record 8 of Set 5 | caravelas
# Processing Record 9 of Set 5 | pahrump
# Processing Record 10 of Set 5 | kalga
# Processing Record 11 of Set 5 | kavieng
# Processing Record 12 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 5 | bloemfontein
# Processing Record 14 of Set 5 | port hardy
# Processing Record 15 of Set 5 | lander
# Processing Record 16 of Set 5 | san jose de sisa
# Processing Record 17 of Set 5 | mumford
# Processing Record 18 of Set 5 | dalbandin
# Processing Record 19 of Set 5 | poum
# Processing Record 20 of Set 5 | acapulco
# Processing Record 21 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 22 of Set 5 | praia
# Processing Record 23 of Set 5 | iquitos
# Processing Record 24 of Set 5 | kidal
# Processing Record 25 of Set 5 | kasungu
# Processing Record 26 of Set 5 | manokwari
# Processing Record 27 of Set 5 | wanning
# Processing Record 28 of Set 5 | constitucion
# Processing Record 29 of Set 5 | solhan
# Processing Record 30 of Set 5 | samarai
# Processing Record 31 of Set 5 | uusikaupunki
# Processing Record 32 of Set 5 | ust-nera
# Processing Record 33 of Set 5 | dhenkanal
# Processing Record 34 of Set 5 | nadym
# Processing Record 35 of Set 5 | santiago
# Processing Record 36 of Set 5 | redkino
# Processing Record 37 of Set 5 | chapais
# Processing Record 38 of Set 5 | loukhi
# Processing Record 39 of Set 5 | namibe
# Processing Record 40 of Set 5 | vardo
# Processing Record 41 of Set 5 | mchinji
# Processing Record 42 of Set 5 | pitogo
# Processing Record 43 of Set 5 | zachagansk
# City not found. Skipping...
# Processing Record 44 of Set 5 | ilulissat
# Processing Record 45 of Set 5 | guelengdeng
# City not found. Skipping...
# Processing Record 46 of Set 5 | broken hill
# Processing Record 47 of Set 5 | sungaipenuh
# Processing Record 48 of Set 5 | andijon
# Processing Record 49 of Set 5 | price
# Processing Record 50 of Set 5 | cimitarra
# Processing Record 1 of Set 6 | bengkulu
# Processing Record 2 of Set 6 | kulhudhuffushi
# Processing Record 3 of Set 6 | arvika
# Processing Record 4 of Set 6 | san quintin
# Processing Record 5 of Set 6 | rocha
# Processing Record 6 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 7 of Set 6 | penha
# Processing Record 8 of Set 6 | cap malheureux
# Processing Record 9 of Set 6 | vila velha
# Processing Record 10 of Set 6 | najran
# Processing Record 11 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 6 | richards bay
# Processing Record 13 of Set 6 | avarua
# Processing Record 14 of Set 6 | beinamar
# Processing Record 15 of Set 6 | tairua
# Processing Record 16 of Set 6 | east london
# Processing Record 17 of Set 6 | baykit
# Processing Record 18 of Set 6 | codrington
# Processing Record 19 of Set 6 | udachnyy
# Processing Record 20 of Set 6 | nabire
# Processing Record 21 of Set 6 | damghan
# Processing Record 22 of Set 6 | kudahuvadhoo
# Processing Record 23 of Set 6 | pisco
# Processing Record 24 of Set 6 | changji
# Processing Record 25 of Set 6 | le port
# Processing Record 26 of Set 6 | vila franca do campo
# Processing Record 27 of Set 6 | sambava
# Processing Record 28 of Set 6 | alofi
# Processing Record 29 of Set 6 | kabinda
# Processing Record 30 of Set 6 | ina
# Processing Record 31 of Set 6 | urumqi
# Processing Record 32 of Set 6 | sitka
# Processing Record 33 of Set 6 | gejiu
# Processing Record 34 of Set 6 | buqayq
# City not found. Skipping...
# Processing Record 35 of Set 6 | grand gaube
# Processing Record 36 of Set 6 | hobyo
# Processing Record 37 of Set 6 | maragogi
# Processing Record 38 of Set 6 | mechoacan
# City not found. Skipping...
# Processing Record 39 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 40 of Set 6 | clyde river
# Processing Record 41 of Set 6 | oppdal
# Processing Record 42 of Set 6 | yelniki
# Processing Record 43 of Set 6 | barrow
# Processing Record 44 of Set 6 | kharp
# Processing Record 45 of Set 6 | mount gambier
# Processing Record 46 of Set 6 | nome
# Processing Record 47 of Set 6 | taoudenni
# Processing Record 48 of Set 6 | halifax
# Processing Record 49 of Set 6 | aleppo
# Processing Record 50 of Set 6 | san patricio
# Processing Record 1 of Set 7 | tuatapere
# Processing Record 2 of Set 7 | luwuk
# Processing Record 3 of Set 7 | calvia
# Processing Record 4 of Set 7 | maturin
# Processing Record 5 of Set 7 | burayevo
# Processing Record 6 of Set 7 | chokurdakh
# Processing Record 7 of Set 7 | cayhagan
# Processing Record 8 of Set 7 | ust-kulom
# Processing Record 9 of Set 7 | bokspits
# City not found. Skipping...
# Processing Record 10 of Set 7 | belmonte
# Processing Record 11 of Set 7 | potosi
# Processing Record 12 of Set 7 | saint-augustin
# Processing Record 13 of Set 7 | kampene
# Processing Record 14 of Set 7 | zhezkazgan
# Processing Record 15 of Set 7 | aswan
# Processing Record 16 of Set 7 | kamaishi
# Processing Record 17 of Set 7 | gollere
# City not found. Skipping...
# Processing Record 18 of Set 7 | okha
# Processing Record 19 of Set 7 | san pedro de macoris
# Processing Record 20 of Set 7 | kamenka
# Processing Record 21 of Set 7 | aksay
# Processing Record 22 of Set 7 | waipawa
# Processing Record 23 of Set 7 | sobolevo
# Processing Record 24 of Set 7 | alexandria
# Processing Record 25 of Set 7 | esperance
# Processing Record 26 of Set 7 | provideniya
# Processing Record 27 of Set 7 | raudeberg
# Processing Record 28 of Set 7 | naryan-mar
# Processing Record 29 of Set 7 | svay rieng
# Processing Record 30 of Set 7 | west sacramento
# Processing Record 31 of Set 7 | chuchkovo
# Processing Record 32 of Set 7 | khandyga
# Processing Record 33 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 7 | jahrom
# City not found. Skipping...
# Processing Record 35 of Set 7 | fort nelson
# Processing Record 36 of Set 7 | odweyne
# Processing Record 37 of Set 7 | saint-pierre
# Processing Record 38 of Set 7 | zharkovskiy
# Processing Record 39 of Set 7 | stepnyak
# Processing Record 40 of Set 7 | kailua
# Processing Record 41 of Set 7 | bharuch
# Processing Record 42 of Set 7 | hermagor
# Processing Record 43 of Set 7 | brzeg
# Processing Record 44 of Set 7 | dhidhdhoo
# Processing Record 45 of Set 7 | vanimo
# Processing Record 46 of Set 7 | vadamadurai
# Processing Record 47 of Set 7 | formiga
# Processing Record 48 of Set 7 | nerchinskiy zavod
# Processing Record 49 of Set 7 | lazaro cardenas
# Processing Record 50 of Set 7 | cabo rojo
# Processing Record 1 of Set 8 | krasnoborsk
# Processing Record 2 of Set 8 | artyom
# Processing Record 3 of Set 8 | cape girardeau
# Processing Record 4 of Set 8 | north bend
# Processing Record 5 of Set 8 | bafra
# Processing Record 6 of Set 8 | mwene-ditu
# Processing Record 7 of Set 8 | newport
# Processing Record 8 of Set 8 | flinders
# Processing Record 9 of Set 8 | hakui
# Processing Record 10 of Set 8 | kaitangata
# Processing Record 11 of Set 8 | lima
# Processing Record 12 of Set 8 | ostrovnoy
# Processing Record 13 of Set 8 | te anau
# Processing Record 14 of Set 8 | gemena
# Processing Record 15 of Set 8 | victoria
# Processing Record 16 of Set 8 | choucheng
# City not found. Skipping...
# Processing Record 17 of Set 8 | chernogorsk
# Processing Record 18 of Set 8 | bunia
# Processing Record 19 of Set 8 | zhigansk
# Processing Record 20 of Set 8 | zakamensk
# Processing Record 21 of Set 8 | kavaratti
# Processing Record 22 of Set 8 | atasu
# Processing Record 23 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 8 | port-gentil
# Processing Record 25 of Set 8 | awbari
# Processing Record 26 of Set 8 | abu zabad
# Processing Record 27 of Set 8 | russell
# Processing Record 28 of Set 8 | umm lajj
# Processing Record 29 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 30 of Set 8 | dubbo
# Processing Record 31 of Set 8 | miraflores
# Processing Record 32 of Set 8 | jarwal
# Processing Record 33 of Set 8 | keetmanshoop
# Processing Record 34 of Set 8 | cherepovets
# Processing Record 35 of Set 8 | karabash
# Processing Record 36 of Set 8 | langham
# Processing Record 37 of Set 8 | matara
# Processing Record 38 of Set 8 | pangai
# Processing Record 39 of Set 8 | filadelfia
# Processing Record 40 of Set 8 | gogrial
# Processing Record 41 of Set 8 | muzhi
# Processing Record 42 of Set 8 | honggang
# Processing Record 43 of Set 8 | klamath falls
# Processing Record 44 of Set 8 | wahran
# City not found. Skipping...
# Processing Record 45 of Set 8 | mlonggo
# Processing Record 46 of Set 8 | primorsk
# Processing Record 47 of Set 8 | srednekolymsk
# Processing Record 48 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 8 | roald
# Processing Record 50 of Set 8 | sorland
# Processing Record 1 of Set 9 | sanchazi
# Processing Record 2 of Set 9 | hirara
# Processing Record 3 of Set 9 | honningsvag
# Processing Record 4 of Set 9 | arman
# Processing Record 5 of Set 9 | la palma
# Processing Record 6 of Set 9 | ust-omchug
# Processing Record 7 of Set 9 | aneho
# Processing Record 8 of Set 9 | byron bay
# Processing Record 9 of Set 9 | laurel
# Processing Record 10 of Set 9 | komsomolskiy
# Processing Record 11 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 12 of Set 9 | sinegorskiy
# Processing Record 13 of Set 9 | mehamn
# Processing Record 14 of Set 9 | catamarca
# Processing Record 15 of Set 9 | dukat
# Processing Record 16 of Set 9 | yaring
# Processing Record 17 of Set 9 | georgetown
# Processing Record 18 of Set 9 | morondava
# Processing Record 19 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 20 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 21 of Set 9 | asau
# Processing Record 22 of Set 9 | mwingi
# Processing Record 23 of Set 9 | conceicao da barra
# Processing Record 24 of Set 9 | jibuti
# Processing Record 25 of Set 9 | airai
# Processing Record 26 of Set 9 | ossora
# Processing Record 27 of Set 9 | deputatskiy
# Processing Record 28 of Set 9 | belovo
# Processing Record 29 of Set 9 | bucerias
# Processing Record 30 of Set 9 | atyrau
# Processing Record 31 of Set 9 | xilopolis
# Processing Record 32 of Set 9 | necochea
# Processing Record 33 of Set 9 | meulaboh
# Processing Record 34 of Set 9 | anadyr
# Processing Record 35 of Set 9 | skjervoy
# Processing Record 36 of Set 9 | alice springs
# Processing Record 37 of Set 9 | kimi
# City not found. Skipping...
# Processing Record 38 of Set 9 | yerbogachen
# Processing Record 39 of Set 9 | ternate
# Processing Record 40 of Set 9 | khromtau
# Processing Record 41 of Set 9 | taltal
# Processing Record 42 of Set 9 | hay river
# Processing Record 43 of Set 9 | fairview
# Processing Record 44 of Set 9 | ahuimanu
# Processing Record 45 of Set 9 | qaqortoq
# Processing Record 46 of Set 9 | vangaindrano
# Processing Record 47 of Set 9 | pochutla
# Processing Record 48 of Set 9 | santa luzia
# Processing Record 49 of Set 9 | ucluelet
# Processing Record 50 of Set 9 | cap-aux-meules
# Processing Record 1 of Set 10 | nouadhibou
# Processing Record 2 of Set 10 | shaowu
# Processing Record 3 of Set 10 | porto seguro
# Processing Record 4 of Set 10 | nagato
# Processing Record 5 of Set 10 | ayan
# Processing Record 6 of Set 10 | geraldton
# Processing Record 7 of Set 10 | tiarei
# Processing Record 8 of Set 10 | sibolga
# Processing Record 9 of Set 10 | mount isa
# Processing Record 10 of Set 10 | tazovskiy
# Processing Record 11 of Set 10 | champerico
# Processing Record 12 of Set 10 | margate
# Processing Record 13 of Set 10 | hofn
# Processing Record 14 of Set 10 | astoria
# Processing Record 15 of Set 10 | niamtougou
# Processing Record 16 of Set 10 | anahuac
# Processing Record 17 of Set 10 | brielle
# Processing Record 18 of Set 10 | saint-joseph
# Processing Record 19 of Set 10 | svetlyy
# Processing Record 20 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 10 | pedernales
# Processing Record 22 of Set 10 | ketchikan
# Processing Record 23 of Set 10 | kyabram
# Processing Record 24 of Set 10 | loreto
# Processing Record 25 of Set 10 | imbituba
# Processing Record 26 of Set 10 | vershino-darasunskiy
# Processing Record 27 of Set 10 | saint george
# Processing Record 28 of Set 10 | yenagoa
# Processing Record 29 of Set 10 | yumen
# Processing Record 30 of Set 10 | port lincoln
# Processing Record 31 of Set 10 | port moresby
# Processing Record 32 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 33 of Set 10 | yablonovo
# Processing Record 34 of Set 10 | lavrentiya
# Processing Record 35 of Set 10 | palkaka
# City not found. Skipping...
# Processing Record 36 of Set 10 | adra
# Processing Record 37 of Set 10 | bulgan
# Processing Record 38 of Set 10 | bani walid
# Processing Record 39 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 40 of Set 10 | faya
# Processing Record 41 of Set 10 | palu
# Processing Record 42 of Set 10 | imeni poliny osipenko
# Processing Record 43 of Set 10 | hamilton
# Processing Record 44 of Set 10 | bud
# Processing Record 45 of Set 10 | oum hadjer
# Processing Record 46 of Set 10 | tezu
# Processing Record 47 of Set 10 | sarishabari
# Processing Record 48 of Set 10 | edd
# Processing Record 49 of Set 10 | tura
# Processing Record 50 of Set 10 | ornskoldsvik
# Processing Record 1 of Set 11 | kondinskoye
# Processing Record 2 of Set 11 | xai-xai
# Processing Record 3 of Set 11 | litoral del san juan
# City not found. Skipping...
# Processing Record 4 of Set 11 | plymouth
# Processing Record 5 of Set 11 | plyussa
# Processing Record 6 of Set 11 | mastic beach
# Processing Record 7 of Set 11 | breves
# Processing Record 8 of Set 11 | grindavik
# Processing Record 9 of Set 11 | pacific grove
# Processing Record 10 of Set 11 | nishihara
# Processing Record 11 of Set 11 | kieta
# Processing Record 12 of Set 11 | mnogovershinnyy
# Processing Record 13 of Set 11 | channel-port aux basques
# Processing Record 14 of Set 11 | berlevag
# Processing Record 15 of Set 11 | saint-francois
# Processing Record 16 of Set 11 | inhambane
# Processing Record 17 of Set 11 | adamovka
# Processing Record 18 of Set 11 | zonguldak
# Processing Record 19 of Set 11 | matucana
# Processing Record 20 of Set 11 | cairns
# Processing Record 21 of Set 11 | yakeshi
# Processing Record 22 of Set 11 | iroquois falls
# Processing Record 23 of Set 11 | constantine
# Processing Record 24 of Set 11 | quelimane
# Processing Record 25 of Set 11 | kroya
# Processing Record 26 of Set 11 | bilibino
# Processing Record 27 of Set 11 | prince rupert
# Processing Record 28 of Set 11 | morro bay
# Processing Record 29 of Set 11 | makat
# Processing Record 30 of Set 11 | shache
# Processing Record 31 of Set 11 | konstantinovka
# Processing Record 32 of Set 11 | reconquista
# Processing Record 33 of Set 11 | languyan
# Processing Record 34 of Set 11 | kuryk
# Processing Record 35 of Set 11 | picota
# Processing Record 36 of Set 11 | karakendzha
# City not found. Skipping...
# Processing Record 37 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 38 of Set 11 | majene
# Processing Record 39 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 40 of Set 11 | sataua
# City not found. Skipping...
# Processing Record 41 of Set 11 | soldatskiy
# City not found. Skipping...
# Processing Record 42 of Set 11 | una
# Processing Record 43 of Set 11 | soe
# Processing Record 44 of Set 11 | ellsworth
# Processing Record 45 of Set 11 | ndioum
# Processing Record 46 of Set 11 | amahai
# Processing Record 47 of Set 11 | san pedro
# Processing Record 48 of Set 11 | tessalit
# Processing Record 49 of Set 11 | manyana
# Processing Record 50 of Set 11 | broome
# Processing Record 1 of Set 12 | moirang
# Processing Record 2 of Set 12 | arraial do cabo
# Processing Record 3 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 12 | puro
# Processing Record 5 of Set 12 | petukhovo
# Processing Record 6 of Set 12 | baruun-urt
# Processing Record 7 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 12 | porteirinha
# Processing Record 9 of Set 12 | itoman
# Processing Record 10 of Set 12 | santa maria
# Processing Record 11 of Set 12 | wilmington island
# Processing Record 12 of Set 12 | maunabo
# Processing Record 13 of Set 12 | sorong
# Processing Record 14 of Set 12 | nalut
# Processing Record 15 of Set 12 | padang
# Processing Record 16 of Set 12 | port macquarie
# Processing Record 17 of Set 12 | les cayes
# Processing Record 18 of Set 12 | turukhansk
# Processing Record 19 of Set 12 | svoge
# Processing Record 20 of Set 12 | avera
# Processing Record 21 of Set 12 | meppel
# Processing Record 22 of Set 12 | landau
# Processing Record 23 of Set 12 | kibala
# Processing Record 24 of Set 12 | catalao
# Processing Record 25 of Set 12 | belaya gora
# Processing Record 26 of Set 12 | muroto
# Processing Record 27 of Set 12 | taloqan
# Processing Record 28 of Set 12 | bazaliya
# Processing Record 29 of Set 12 | abbeville
# Processing Record 30 of Set 12 | sinnamary
# Processing Record 31 of Set 12 | kinston
# Processing Record 32 of Set 12 | kununurra
# Processing Record 33 of Set 12 | masuguru
# Processing Record 34 of Set 12 | lorengau
# Processing Record 35 of Set 12 | neka
# Processing Record 36 of Set 12 | keffi
# Processing Record 37 of Set 12 | opuwo
# Processing Record 38 of Set 12 | lieksa
# Processing Record 39 of Set 12 | darhan
# Processing Record 40 of Set 12 | sosnogorsk
# Processing Record 41 of Set 12 | alihe
# Processing Record 42 of Set 12 | akdepe
# Processing Record 43 of Set 12 | cimahi
# Processing Record 44 of Set 12 | salina cruz
# Processing Record 45 of Set 12 | altus
# Processing Record 46 of Set 12 | batsfjord
# Processing Record 47 of Set 12 | beruwala
# Processing Record 48 of Set 12 | karlskoga
# Processing Record 49 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 50 of Set 12 | goulburn
# Processing Record 1 of Set 13 | wagar
# Processing Record 2 of Set 13 | yar-sale
# Processing Record 3 of Set 13 | morehead
# Processing Record 4 of Set 13 | kerteh
# City not found. Skipping...
# Processing Record 5 of Set 13 | heihe
# Processing Record 6 of Set 13 | banda aceh
# Processing Record 7 of Set 13 | andenes
# Processing Record 8 of Set 13 | ugoofaaru
# Processing Record 9 of Set 13 | tuscaloosa
# Processing Record 10 of Set 13 | flin flon
# Processing Record 11 of Set 13 | quatre cocos
# Processing Record 12 of Set 13 | barcelos
# Processing Record 13 of Set 13 | novodugino
# Processing Record 14 of Set 13 | turtas
# Processing Record 15 of Set 13 | del rio
# Processing Record 16 of Set 13 | iquique
# Processing Record 17 of Set 13 | lipin bor
# Processing Record 18 of Set 13 | mapiripan
# Processing Record 19 of Set 13 | oussouye
# Processing Record 20 of Set 13 | kupang
# Processing Record 21 of Set 13 | caernarfon
# Processing Record 22 of Set 13 | cam ranh
# Processing Record 23 of Set 13 | kalaleh
# Processing Record 24 of Set 13 | rawlins
# Processing Record 25 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 26 of Set 13 | aranos
# Processing Record 27 of Set 13 | baisha
# Processing Record 28 of Set 13 | batemans bay
# Processing Record 29 of Set 13 | teguldet
# Processing Record 30 of Set 13 | afmadu
# City not found. Skipping...
# Processing Record 31 of Set 13 | luau
# Processing Record 32 of Set 13 | fukue
# Processing Record 33 of Set 13 | ambilobe
# Processing Record 34 of Set 13 | yeppoon
# Processing Record 35 of Set 13 | ojinaga
# Processing Record 36 of Set 13 | buzdyak
# Processing Record 37 of Set 13 | georgiyevka
# Processing Record 38 of Set 13 | xiamen
# Processing Record 39 of Set 13 | masvingo
# Processing Record 40 of Set 13 | portland
# Processing Record 41 of Set 13 | lashio
# Processing Record 42 of Set 13 | balabac
# Processing Record 43 of Set 13 | himora
# City not found. Skipping...
# Processing Record 44 of Set 13 | orlik
# Processing Record 45 of Set 13 | coihaique
# Processing Record 46 of Set 13 | kolomna
# Processing Record 47 of Set 13 | marsa matruh
# Processing Record 48 of Set 13 | mahibadhoo
# Processing Record 49 of Set 13 | sola
# Processing Record 50 of Set 13 | londiani
# Processing Record 1 of Set 14 | manaure
# Processing Record 2 of Set 14 | nyurba
# Processing Record 3 of Set 14 | camana
# Processing Record 4 of Set 14 | kushmurun
# Processing Record 5 of Set 14 | senanga
# Processing Record 6 of Set 14 | saravan
# Processing Record 7 of Set 14 | diego de almagro
# Processing Record 8 of Set 14 | souillac
# Processing Record 9 of Set 14 | copiapo
# Processing Record 10 of Set 14 | sagua la grande
# Processing Record 11 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 12 of Set 14 | riyadh
# Processing Record 13 of Set 14 | caluquembe
# Processing Record 14 of Set 14 | zeya
# Processing Record 15 of Set 14 | cazaje
# City not found. Skipping...
# Processing Record 16 of Set 14 | pilar
# Processing Record 17 of Set 14 | machali
# Processing Record 18 of Set 14 | torbat-e jam
# Processing Record 19 of Set 14 | coronado
# Processing Record 20 of Set 14 | bolshoye selo
# Processing Record 21 of Set 14 | bow island
# Processing Record 22 of Set 14 | bandar-e lengeh
# Processing Record 23 of Set 14 | carolina
# Processing Record 24 of Set 14 | tulum
# Processing Record 25 of Set 14 | gannan
# Processing Record 26 of Set 14 | gao
# Processing Record 27 of Set 14 | jumla
# Processing Record 28 of Set 14 | haines junction
# Processing Record 29 of Set 14 | skagastrond
# City not found. Skipping...
# Processing Record 30 of Set 14 | beipiao
# Processing Record 31 of Set 14 | digha
# Processing Record 32 of Set 14 | kloulklubed
# Processing Record 33 of Set 14 | primorsko-akhtarsk
# Processing Record 34 of Set 14 | le vauclin
# Processing Record 35 of Set 14 | olinda
# Processing Record 36 of Set 14 | kachikau
# City not found. Skipping...
# Processing Record 37 of Set 14 | bethlehem
# Processing Record 38 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 14 | half moon bay
# Processing Record 40 of Set 14 | laguna
# Processing Record 41 of Set 14 | noumea
# Processing Record 42 of Set 14 | singaraja
# Processing Record 43 of Set 14 | rovaniemi
# Processing Record 44 of Set 14 | atar
# Processing Record 45 of Set 14 | viedma
# Processing Record 46 of Set 14 | san luis
# Processing Record 47 of Set 14 | burica
# City not found. Skipping...
# Processing Record 48 of Set 14 | karanja
# Processing Record 49 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 50 of Set 14 | jinka
# Processing Record 1 of Set 15 | muscatine
# Processing Record 2 of Set 15 | vao
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 640

# %%
# converting array of dictinaries to DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Punta Arenas -53.1500  -70.9167     64.40        59          75
# 1          George -33.9630   22.4617     64.40        94          20
# 2    Puerto Ayora  -0.7393  -90.3518     86.00        66           0
# 3  Ribeira Grande  38.5167  -28.7000     53.60        66          40
# 4           Bluff -46.6000  168.3333     52.29        71         100
# 5          Cassia -20.5831  -46.9219     80.06        79          81
# 6        Havelock  34.8791  -76.9013     50.00        29          20
# 7         Maumere  -8.6199  122.2111     78.82        81         100
# 8          Hobart -42.8794  147.3294     57.99       100          90
# 9          Yulara -25.2406  130.9889     86.00        17          90
#
#    Wind Speed Country                 Date
# 0       14.97      CL  2021-02-03 20:04:29
# 1        5.75      ZA  2021-02-03 20:04:29
# 2       21.85      EC  2021-02-03 20:03:40
# 3       26.46      PT  2021-02-03 20:02:51
# 4       15.03      NZ  2021-02-03 20:00:32
# 5        2.26      BR  2021-02-03 20:04:29
# 6       20.71      US  2021-02-03 20:04:29
# 7        7.87      ID  2021-02-03 20:04:30
# 8        4.61      AU  2021-02-03 20:00:19
# 9        4.61      AU  2021-02-03 20:01:12

# %%
# reorder columns in DataFrame
new_order = ['City', 'Country', 'Date', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed']

city_data_df = city_data_df[new_order]
city_data_df.head()
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0    Punta Arenas      CL  2021-02-03 20:04:29 -53.1500  -70.9167     64.40
# 1          George      ZA  2021-02-03 20:04:29 -33.9630   22.4617     64.40
# 2    Puerto Ayora      EC  2021-02-03 20:03:40  -0.7393  -90.3518     86.00
# 3  Ribeira Grande      PT  2021-02-03 20:02:51  38.5167  -28.7000     53.60
# 4           Bluff      NZ  2021-02-03 20:00:32 -46.6000  168.3333     52.29
#
#    Humidity  Cloudiness  Wind Speed
# 0        59          75       14.97
# 1        94          20        5.75
# 2        66           0       21.85
# 3        66          40       26.46
# 4        71         100       15.03

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time
# creating scatter plot for latitude vs max temp.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("City Latitude vs Max Temperature " + time.strftime("%x"))
plt.grid=True

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# creating scatter plot for latitude vs humidity
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs Humidity " + time.strftime("%x"))
plt.grid=True

# Save the figure.
plt.savefig("weather_data/Fig2.png")

# Show plot.
plt.show()

# %%
# creating scatter plot for latitude vs cloudiness
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs Cloudiness " + time.strftime("%x"))
plt.grid=True

# Save the figure.
plt.savefig("weather_data/Fig3.png")

# Show plot.
plt.show()

# %%
# creating scatter plot for latitude vs wind speed
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("City Latitude vs Wind Speed " + time.strftime("%x"))
plt.grid=True

# Save the figure.
plt.savefig("weather_data/Fig4.png")

# Show plot.
plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values, "r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel('Latitude')
    plt.title(title)
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df.loc[13]
index13
# Out:
# City                    Namatanai
# Country                        PG
# Date          2021-02-03 20:04:30
# Lat                       -3.6667
# Lng                       152.433
# Max Temp                     79.7
# Humidity                       83
# Cloudiness                    100
# Wind Speed                   6.93
# Name: 13, dtype: object

# %%
# filtering the northern hemisphere coordinates
northern_hemi_df = city_data_df.loc[(city_data_df['Lat']>=0)]
northern_hemi_df.head()
# Out:
#               City Country                 Date      Lat       Lng  Max Temp  \
# 3   Ribeira Grande      PT  2021-02-03 20:02:51  38.5167  -28.7000     53.60
# 6         Havelock      US  2021-02-03 20:04:29  34.8791  -76.9013     50.00
# 10        Khatanga      RU  2021-02-03 20:03:35  71.9667  102.5000     -5.78
# 11         Savinka      RU  2021-02-03 20:04:30  50.0785   47.0994     36.39
# 15          Kodiak      US  2021-02-03 20:02:50  57.7900 -152.4072     28.40
#
#     Humidity  Cloudiness  Wind Speed
# 3         66          40       26.46
# 6         29          20       20.71
# 10        91         100        8.77
# 11        99         100        6.22
# 15        93           1        3.44

# %%
# filtering the southern hemisphere coordinates
southern_hemi_df = city_data_df.loc[(city_data_df['Lat']<0)]
southern_hemi_df.head()
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0  Punta Arenas      CL  2021-02-03 20:04:29 -53.1500  -70.9167     64.40
# 1        George      ZA  2021-02-03 20:04:29 -33.9630   22.4617     64.40
# 2  Puerto Ayora      EC  2021-02-03 20:03:40  -0.7393  -90.3518     86.00
# 4         Bluff      NZ  2021-02-03 20:00:32 -46.6000  168.3333     52.29
# 5        Cassia      BR  2021-02-03 20:04:29 -20.5831  -46.9219     80.06
#
#    Humidity  Cloudiness  Wind Speed
# 0        59          75       14.97
# 1        94          20        5.75
# 2        66           0       21.85
# 4        71         100       15.03
# 5        79          81        2.26

# %%
# linear regression on northern hemisphere on max temp.
x_values = northern_hemi_df['Lat']
y_values= northern_hemi_df['Max Temp']

plot_linear_regression(x_values, y_values, 'Linear Regression on the Northern Hemisphere\nfor Maximum Temperature',
                       'Max Temp',(0, -40))

# %%
# linear regression on southern hemisphere on max temp.
x_values = southern_hemi_df['Lat']
y_values= southern_hemi_df['Max Temp']

plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for Maximum Temperature',
                       'Max Temp',(-50,45))

# %%
# linear regression on northern hemisphere on humidity
x_values = northern_hemi_df['Lat']
y_values= northern_hemi_df['Humidity']
plot_linear_regression(x_values, y_values, 'Linear Regression on the Northern Hemisphere \n for % Humidity',
                       '% Humidity',(40,10))

# %%
# linear regression on southern hemisphere on humidity
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df['Humidity']

plot_linear_regression(x_values, y_values, 'Linear Regression on the Southern Hemisphere\n for % Humidity', '% Humidity',
                       (-22, 30))

# %%
# linear regression on northern hemisphere on cloudiness
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df['Cloudiness']

plot_linear_regression(x_values, y_values, 'Linear Regression on the Northern Hemisphere\n for % Cloudiness',
                       '% Cloudiness',(40, 40))

# %%
# linear regression on southern hemisphere on cloudiness
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df['Cloudiness']

plot_linear_regression(x_values, y_values, 'Linear Regression on the Southern Hemisphere\n for % Cloudiness',
                       '% Cloudiness',(-25, 30))

# %%
# linear regression on northern hemisphere on wind speed
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df['Wind Speed']

plot_linear_regression(x_values, y_values, 'Linear Regression on the Northern Hemisphere\n for Wind Speed',
                       'Wind Speed',(0, 50))

# %%
# linear regression on southern hemisphere on wind speed
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df['Wind Speed']

plot_linear_regression(x_values, y_values, 'Linear Regression on the Southern Hemisphere\n for Wind Speed',
                       'Wind Speed',(-22, 30))
